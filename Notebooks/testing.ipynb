# %%
import joblib

model = joblib.load("../models/calorie_model.pkl")

sample = [[13, 5, 3, 2,9]]  # protein, fiber, fat, sugar
prediction = model.predict(sample)

print("Prediksi Kalori:", prediction)
# Out:
# Prediksi Kalori: [103.70099218]
# c:\Users\black\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
